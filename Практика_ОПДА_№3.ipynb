# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaSokolova111/OPDA/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%9E%D0%9F%D0%94%D0%90_%E2%84%963.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
import pandas as pd

df = pd.DataFrame({
    'Страна': ['США', 'Китай', 'Россия', 'Турция', 'ЮАР', 'vd', 'sdd', 'dss'],
    '2018 год': [20612, 13842, 1665, 780, 368, 555,111,888],
    '2019 год': [21433, 14402, 1702, 761, 351, 557, 887, 444]
})
df.sample(5)
# Out:
#    Страна  2018 год  2019 год
# 7     dss       888       444
# 4     ЮАР       368       351
# 3  Турция       780       761
# 5      vd       555       557
# 0     США     20612     21433

# %%
import pandas as pd

df = pd.DataFrame({
    'Страна': ['США', 'Китай', 'Россия', 'Турция', 'ЮАР'],
    '2018 год': [20612, 13842, 1665, 780, 368],
    '2019 год': [21433, 14402, 1702, 761, 351]
} , index=['US', 'CN', 'RU', 'TR', 'ZA']

)

df
# Out:
#     Страна  2018 год  2019 год
# US     США     20612     21433
# CN   Китай     13842     14402
# RU  Россия      1665      1702
# TR  Турция       780       761
# ZA     ЮАР       368       351

# %%
df["Страна"]
# Out:
# US       США
# CN     Китай
# RU    Россия
# TR    Турция
# ZA       ЮАР
# Name: Страна, dtype: object

# %%
df.loc["RU"]
# Out:
# Страна      Россия
# 2018 год      1665
# 2019 год      1702
# Name: RU, dtype: object

# %%
df.iloc[0]
# Out:
# Страна        США
# 2018 год    20612
# 2019 год    21433
# Name: 0, dtype: object

# %%
df[2:]
# Out:
#     Страна  2018 год  2019 год
# RU  Россия      1665      1702
# TR  Турция       780       761
# ZA     ЮАР       368       351

# %%
df[df["2019 год"]> 761]['Страна']
# Out:
# US       США
# CN     Китай
# RU    Россия
# Name: Страна, dtype: object

# %%
df.rename(columns={'2018 год': '2018', '2019 год': '2019'})
# Out:
#     Страна   2018   2019
# US     США  20612  21433
# CN   Китай  13842  14402
# RU  Россия   1665   1702
# TR  Турция    780    761
# ZA     ЮАР    368    351

# %%
dfr=df.rename(columns={'2018 год': '2018', '2019 год': '2019'})

# %%
dfr["Рост"] = dfr['2019'] - dfr['2018']

dfr
# Out:
#     Страна   2018   2019  Рост
# US     США  20612  21433   821
# CN   Китай  13842  14402   560
# RU  Россия   1665   1702    37
# TR  Турция    780    761   -19
# ZA     ЮАР    368    351   -17

# %%
dfr.drop(["Рост"], axis="columns")
# Out:
#     Страна   2018   2019
# US     США  20612  21433
# CN   Китай  13842  14402
# RU  Россия   1665   1702
# TR  Турция    780    761
# ZA     ЮАР    368    351

# %%
dfr2=dfr.drop(["Рост"], axis="columns")
dfr2
# Out:
#     Страна   2018   2019
# US     США  20612  21433
# CN   Китай  13842  14402
# RU  Россия   1665   1702
# TR  Турция    780    761
# ZA     ЮАР    368    351

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44528493-b933-4cd2-b64e-1a6a13b0e748" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44528493-b933-4cd2-b64e-1a6a13b0e748">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data-6322-2021-02-24.csv to data-6322-2021-02-24.csv

# %%
df = pd.read_csv("data-6322-2021-02-24.csv", sep=';')

df

my_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-596c4b6a7812> in <module>()
# ----> 1 df = pd.read_csv("data-6322-2021-02-24.csv", sep=';')
#       2
#       3 df
#       4
#       5 my_df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data-6322-2021-02-24.csv'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-69edb5b5-9aa7-4025-9183-630439c1d513" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69edb5b5-9aa7-4025-9183-630439c1d513">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Копия data-6322-2021-02-24.xlsx to Копия data-6322-2021-02-24.xlsx

# %%
data_xlsx = pd.read_excel("Копия data-6322-2021-02-24.xlsx")

# %%
data_xlsx
# Out:
#        ID  ...   global_id
# 0       1  ...    39801229
# 1       2  ...    39801230
# 2       3  ...    39801231
# 3       4  ...    39801232
# 4       5  ...    39801233
# ..    ...  ...         ...
# 870  1695  ...  1062032572
# 871  1696  ...  1082826142
# 872  1697  ...  1082826143
# 873  1698  ...  1092182091
# 874  1699  ...  1092182092
#
# [875 rows x 12 columns]

# %%
import pandas as pd

df = pd.DataFrame({
    'Страна': ['США', 'Китай', 'Россия', 'Турция', 'ЮАР'],
    '2018 год': [20612, 13842, 1665, 780, 368],
    '2019 год': [21433, 14402, 1702, 761, 351],
}, index=['US', 'CN', 'RU', 'TR', 'ZA']

)

df.to_csv("coutry.csv",encoding='cp1251')

# %%
from google.colab import files
files.download("coutry.csv")

# %%
import pandas as pd

df = pd.DataFrame({
    'Страна': ['США', 'Китай', 'Россия', 'Турция', 'ЮАР'],
    '2018 год': [20612, 13842, 1665, 780, 368],
    '2019 год': [21433, 14402, 1702, 761, 351],
}, index=['US', 'CN', 'RU', 'TR', 'ZA']

)

df.to_excel("coutry.xlsx",encoding='cp1251')

# %%
from google.colab import files
files.download("coutry.xlsx")

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='barh', y='2018 год', color='red')
plt.show()

# %%
df.plot(kind='barh', y='2019 год', color='blue')
plt.show()

# %%
df.pivot(columns="Страна").plot(kind='bar')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
tables = pd.read_html(
    'https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D1%81%D1%82%D1%80%D0%B0%D0%BD_%D0%BF%D0%BE_%D0%92%D0%92%D0%9F_(%D0%BD%D0%BE%D0%BC%D0%B8%D0%BD%D0%B0%D0%BB)',
    match='Страна')

# %%
len(tables)
# Out:
# 4

# %%
df = tables[1]
df
# Out:
#        №              Страна   2018   2019
# 0      1                 США  20612  21433
# 1      2               Китай  13842  14402
# 2      3              Япония   4952   5080
# 3      4            Германия   3966   3862
# 4      5               Индия   2713   2869
# ..   ...                 ...    ...    ...
# 188  183  Маршалловы Острова     22     23
# 189  184            Кирибати      2      2
# 190  185               Науру     12     12
# 191  186              Тувалу      5      5
# 192  NaN        Всего в мире  85690  87552
#
# [193 rows x 4 columns]

# %%
df.drop(('№'), axis=1, inplace=True)

# %%
df
# Out:
#                  Страна   2018   2019
# 0                   США  20612  21433
# 1                 Китай  13842  14402
# 2                Япония   4952   5080
# 3              Германия   3966   3862
# 4                 Индия   2713   2869
# ..                  ...    ...    ...
# 188  Маршалловы Острова     22     23
# 189            Кирибати      2      2
# 190               Науру     12     12
# 191              Тувалу      5      5
# 192        Всего в мире  85690  87552
#
# [193 rows x 3 columns]

# %%
print(df.to_string())
# Out:
#                        Страна   2018   2019
# 0                         США  20612  21433
# 1                       Китай  13842  14402
# 2                      Япония   4952   5080
# 3                    Германия   3966   3862
# 4                       Индия   2713   2869
# 5              Великобритания   2864   2831
# 6                     Франция   2789   2716
# 7                      Италия   2087   2001
# 8                    Бразилия   1885   1839
# 9                      Канада   1716   1736
# 10                     Россия   1665   1702
# 11           Республика Корея   1725   1647
# 12                    Испания   1420   1394
# 13                  Австралия   1421   1387
# 14                    Мексика   1222   1258
# 15                  Индонезия   1042   1120
# 16                 Нидерланды    914    907
# 17          Саудовская Аравия    787    793
# 18                     Турция    780    761
# 19                  Швейцария    706    705
# 20                    Тайвань    608    611
# 21                     Польша    587    592
# 22                       Иран    435    583
# 23                    Таиланд    506    544
# 24                     Швеция    555    530
# 25                    Бельгия    543    529
# 26                    Нигерия    398    448
# 27                    Австрия    456    446
# 28                  Аргентина    517    444
# 29                        ОАЭ    422    421
# 30                   Норвегия    434    403
# 31                   Ирландия    387    398
# 32                    Израиль    370    394
# 33                  Филиппины    347    377
# 34                   Сингапур    373    372
# 35              Гонконг (КНР)    362    366
# 36                   Малайзия    359    365
# 37                        ЮАР    368    351
# 38                      Дания    356    347
# 39                    Вьетнам    304    330
# 40                   Колумбия    333    324
# 41                  Бангладеш    274    303
# 42                     Египет    250    302
# 43                       Чили    298    282
# 44                   Пакистан    313    276
# 45                  Финляндия    276    269
# 46                      Чехия    249    251
# 47                    Румыния    242    250
# 48                 Португалия    241    238
# 49                       Перу    225    231
# 50                       Ирак    226    230
# 51                     Греция    218    210
# 52             Новая Зеландия    207    205
# 53                  Казахстан    179    182
# 54                      Катар    183    176
# 55                      Алжир    174    169
# 56                    Венгрия    158    161
# 57                 Украина[2]    131    154
# 58                     Кувейт    141    135
# 59                    Марокко    118    119
# 60                    Эквадор    108    107
# 61                   Словакия    106    105
# 62                Пуэрто-Рико    101    103
# 63                      Кения    878    954
# 64                    Эфиопия    802    928
# 65                     Ангола    106    894
# 66   Доминиканская Республика    856    890
# 67                  Шри-Ланка    884    840
# 68                  Гватемала    731    767
# 69                       Оман    798    764
# 70                 Люксембург    710    711
# 71                     Мьянма    667    686
# 72                   Болгария    663    679
# 73                       Гана    655    670
# 74                     Панама    651    668
# 75                  Венесуэла    984    640
# 76                 Белоруссия    600    630
# 77                 Коста-Рика    609    621
# 78                   Хорватия    610    604
# 79                   Танзания    567    608
# 80                Кот-д’Ивуар    577    586
# 81                 Узбекистан    504    580
# 82                    Уругвай    598    567
# 83                      Литва    535    542
# 84                Макао (КНР)    551    539
# 85                   Словения    541    537
# 86                      Ливан    550    526
# 87                     Сербия    506    514
# 88                   ДР Конго    471    498
# 89                Азербайджан    471    480
# 90                  Туркмения    407    452
# 91                   Иордания    430    446
# 92                    Боливия    406    412
# 93                      Ливия    414    398
# 94                    Камерун    387    389
# 95                      Тунис    397    388
# 96                    Бахрейн    377    386
# 97                   Парагвай    404    374
# 98                     Уганда    338    365
# 99                     Латвия    343    341
# 100                     Судан    357    334
# 101                   Эстония    307    315
# 102                     Непал    290    307
# 103                 Сальвадор    261    270
# 104                  Камбоджа    244    267
# 105                  Гондурас    214    250
# 106      Папуа — Новая Гвинея    240    248
# 107                      Кипр    250    246
# 108                  Исландия    257    242
# 109                    Замбия    270    241
# 110         Тринидад и Тобаго    238    241
# 111                   Сенегал    238    236
# 112                     Йемен    235    226
# 113      Босния и Герцеговина    201    199
# 114                      Лаос    181    191
# 115                Афганистан    184    189
# 116                  Зимбабве    208    187
# 117                  Ботсвана    187    185
# 118                      Мали    170    173
# 119                    Грузия    176    177
# 120                     Габон    169    169
# 121                    Ямайка    156    159
# 122              Буркина-Фасо    162    157
# 123                   Албания    151    153
# 124                  Мозамбик    147    152
# 125                    Мальта    147    150
# 126                     Бенин    143    144
# 127                Мадагаскар    139    141
# 128                  Маврикий    141    140
# 129                  Монголия    131    139
# 130                    Гвинея    122    138
# 131                   Армения    125    137
# 132         Багамские Острова    130    136
# 133                    Бруней    136    135
# 134        Северная Македония    126    127
# 135                     Нигер    129    129
# 136                 Никарагуа    130    125
# 137                   Намибия    136    125
# 138          Республика Конго    134    125
# 139                  Молдавия    113    120
# 140     Экваториальная Гвинея    136    118
# 141                       Чад    110    110
# 142                    Руанда    963    101
# 143                     Гаити    966    870
# 144                  Киргизия    827    846
# 145               Таджикистан    752    812
# 146         Республика Косово    795    797
# 147                    Малави    691    767
# 148                Мавритания    705     76
# 149                  Мальдивы    532    576
# 150                      Того    536    546
# 151                     Фиджи    554    541
# 152                  Барбадос    509    521
# 153                    Гайана    479    517
# 154                Черногория    551     50
# 155               Южный Судан    466    493
# 156                  Эсватини    471    459
# 157              Сьерра-Леоне    409    421
# 158                   Суринам    347     37
# 159                   Джибути    301    335
# 160                   Либерия    326    318
# 161                   Бурунди    319    311
# 162        Аруба (Нидерланды)    282    289
# 163                     Бутан    251     25
# 164                    Лесото    247    242
# 165                       ЦАР    228    228
# 166                Сент-Люсия    207    212
# 167                   Эритрея    201    198
# 168                Кабо-Верде    197    198
# 169                     Белиз    187    184
# 170                    Гамбия    166    181
# 171         Антигуа и Барбуда    161    166
# 172       Сейшельские Острова    158    165
# 173           Восточный Тимор    157    162
# 174                Сан-Марино    166     16
# 175        Соломоновы Острова    159     16
# 176              Гвинея-Бисау    151    144
# 177                   Гренада    117    122
# 178                    Коморы    118    119
# 179         Сент-Китс и Невис    101    107
# 180                   Вануату     93     93
# 181                     Самоа     84     85
# 182  Сент-Винсент и Гренадины     81     82
# 183                  Доминика     53     59
# 184                     Тонга     49     52
# 185       Сан-Томе и Принсипи     42     42
# 186                Микронезия     40     41
# 187                     Палау     29     28
# 188        Маршалловы Острова     22     23
# 189                  Кирибати      2      2
# 190                     Науру     12     12
# 191                    Тувалу      5      5
# 192              Всего в мире  85690  87552

# %%
df.replace({'\[[0-9]+\]': ''}, regex=True, inplace=True)

# %%
print(df.to_string())
# Out:
#                        Страна   2018   2019
# 0                         США  20612  21433
# 1                       Китай  13842  14402
# 2                      Япония   4952   5080
# 3                    Германия   3966   3862
# 4                       Индия   2713   2869
# 5              Великобритания   2864   2831
# 6                     Франция   2789   2716
# 7                      Италия   2087   2001
# 8                    Бразилия   1885   1839
# 9                      Канада   1716   1736
# 10                     Россия   1665   1702
# 11           Республика Корея   1725   1647
# 12                    Испания   1420   1394
# 13                  Австралия   1421   1387
# 14                    Мексика   1222   1258
# 15                  Индонезия   1042   1120
# 16                 Нидерланды    914    907
# 17          Саудовская Аравия    787    793
# 18                     Турция    780    761
# 19                  Швейцария    706    705
# 20                    Тайвань    608    611
# 21                     Польша    587    592
# 22                       Иран    435    583
# 23                    Таиланд    506    544
# 24                     Швеция    555    530
# 25                    Бельгия    543    529
# 26                    Нигерия    398    448
# 27                    Австрия    456    446
# 28                  Аргентина    517    444
# 29                        ОАЭ    422    421
# 30                   Норвегия    434    403
# 31                   Ирландия    387    398
# 32                    Израиль    370    394
# 33                  Филиппины    347    377
# 34                   Сингапур    373    372
# 35              Гонконг (КНР)    362    366
# 36                   Малайзия    359    365
# 37                        ЮАР    368    351
# 38                      Дания    356    347
# 39                    Вьетнам    304    330
# 40                   Колумбия    333    324
# 41                  Бангладеш    274    303
# 42                     Египет    250    302
# 43                       Чили    298    282
# 44                   Пакистан    313    276
# 45                  Финляндия    276    269
# 46                      Чехия    249    251
# 47                    Румыния    242    250
# 48                 Португалия    241    238
# 49                       Перу    225    231
# 50                       Ирак    226    230
# 51                     Греция    218    210
# 52             Новая Зеландия    207    205
# 53                  Казахстан    179    182
# 54                      Катар    183    176
# 55                      Алжир    174    169
# 56                    Венгрия    158    161
# 57                    Украина    131    154
# 58                     Кувейт    141    135
# 59                    Марокко    118    119
# 60                    Эквадор    108    107
# 61                   Словакия    106    105
# 62                Пуэрто-Рико    101    103
# 63                      Кения    878    954
# 64                    Эфиопия    802    928
# 65                     Ангола    106    894
# 66   Доминиканская Республика    856    890
# 67                  Шри-Ланка    884    840
# 68                  Гватемала    731    767
# 69                       Оман    798    764
# 70                 Люксембург    710    711
# 71                     Мьянма    667    686
# 72                   Болгария    663    679
# 73                       Гана    655    670
# 74                     Панама    651    668
# 75                  Венесуэла    984    640
# 76                 Белоруссия    600    630
# 77                 Коста-Рика    609    621
# 78                   Хорватия    610    604
# 79                   Танзания    567    608
# 80                Кот-д’Ивуар    577    586
# 81                 Узбекистан    504    580
# 82                    Уругвай    598    567
# 83                      Литва    535    542
# 84                Макао (КНР)    551    539
# 85                   Словения    541    537
# 86                      Ливан    550    526
# 87                     Сербия    506    514
# 88                   ДР Конго    471    498
# 89                Азербайджан    471    480
# 90                  Туркмения    407    452
# 91                   Иордания    430    446
# 92                    Боливия    406    412
# 93                      Ливия    414    398
# 94                    Камерун    387    389
# 95                      Тунис    397    388
# 96                    Бахрейн    377    386
# 97                   Парагвай    404    374
# 98                     Уганда    338    365
# 99                     Латвия    343    341
# 100                     Судан    357    334
# 101                   Эстония    307    315
# 102                     Непал    290    307
# 103                 Сальвадор    261    270
# 104                  Камбоджа    244    267
# 105                  Гондурас    214    250
# 106      Папуа — Новая Гвинея    240    248
# 107                      Кипр    250    246
# 108                  Исландия    257    242
# 109                    Замбия    270    241
# 110         Тринидад и Тобаго    238    241
# 111                   Сенегал    238    236
# 112                     Йемен    235    226
# 113      Босния и Герцеговина    201    199
# 114                      Лаос    181    191
# 115                Афганистан    184    189
# 116                  Зимбабве    208    187
# 117                  Ботсвана    187    185
# 118                      Мали    170    173
# 119                    Грузия    176    177
# 120                     Габон    169    169
# 121                    Ямайка    156    159
# 122              Буркина-Фасо    162    157
# 123                   Албания    151    153
# 124                  Мозамбик    147    152
# 125                    Мальта    147    150
# 126                     Бенин    143    144
# 127                Мадагаскар    139    141
# 128                  Маврикий    141    140
# 129                  Монголия    131    139
# 130                    Гвинея    122    138
# 131                   Армения    125    137
# 132         Багамские Острова    130    136
# 133                    Бруней    136    135
# 134        Северная Македония    126    127
# 135                     Нигер    129    129
# 136                 Никарагуа    130    125
# 137                   Намибия    136    125
# 138          Республика Конго    134    125
# 139                  Молдавия    113    120
# 140     Экваториальная Гвинея    136    118
# 141                       Чад    110    110
# 142                    Руанда    963    101
# 143                     Гаити    966    870
# 144                  Киргизия    827    846
# 145               Таджикистан    752    812
# 146         Республика Косово    795    797
# 147                    Малави    691    767
# 148                Мавритания    705     76
# 149                  Мальдивы    532    576
# 150                      Того    536    546
# 151                     Фиджи    554    541
# 152                  Барбадос    509    521
# 153                    Гайана    479    517
# 154                Черногория    551     50
# 155               Южный Судан    466    493
# 156                  Эсватини    471    459
# 157              Сьерра-Леоне    409    421
# 158                   Суринам    347     37
# 159                   Джибути    301    335
# 160                   Либерия    326    318
# 161                   Бурунди    319    311
# 162        Аруба (Нидерланды)    282    289
# 163                     Бутан    251     25
# 164                    Лесото    247    242
# 165                       ЦАР    228    228
# 166                Сент-Люсия    207    212
# 167                   Эритрея    201    198
# 168                Кабо-Верде    197    198
# 169                     Белиз    187    184
# 170                    Гамбия    166    181
# 171         Антигуа и Барбуда    161    166
# 172       Сейшельские Острова    158    165
# 173           Восточный Тимор    157    162
# 174                Сан-Марино    166     16
# 175        Соломоновы Острова    159     16
# 176              Гвинея-Бисау    151    144
# 177                   Гренада    117    122
# 178                    Коморы    118    119
# 179         Сент-Китс и Невис    101    107
# 180                   Вануату     93     93
# 181                     Самоа     84     85
# 182  Сент-Винсент и Гренадины     81     82
# 183                  Доминика     53     59
# 184                     Тонга     49     52
# 185       Сан-Томе и Принсипи     42     42
# 186                Микронезия     40     41
# 187                     Палау     29     28
# 188        Маршалловы Острова     22     23
# 189                  Кирибати      2      2
# 190                     Науру     12     12
# 191                    Тувалу      5      5
# 192              Всего в мире  85690  87552

# %%
df.drop(df.index[len(df)-1])
# Out:
#                  Страна   2018   2019
# 0                   США  20612  21433
# 1                 Китай  13842  14402
# 2                Япония   4952   5080
# 3              Германия   3966   3862
# 4                 Индия   2713   2869
# ..                  ...    ...    ...
# 187               Палау     29     28
# 188  Маршалловы Острова     22     23
# 189            Кирибати      2      2
# 190               Науру     12     12
# 191              Тувалу      5      5
#
# [192 rows x 3 columns]

# %%
df.to_excel("coutryALL.xlsx",encoding='cp1251')
